# %%
from preprocessor import *
import main 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

from sklearn import linear_model
from sklearn.metrics import mean_squared_error

# %%
main.grams_df.style
# Out:
# <style  type="text/css" >
# ...

# %%
#Tech category with the monetary impact
musv=main.grams_df['music']['monetary_impact']

# %%
#try to graph a histogram with the monetary impact distribution
xs = np.arange(musv.min(), musv.max(), 0.1)
fit = stats.norm.pdf(xs, np.mean(musv), np.std(musv))
plt.plot(xs, fit, label='Normal Dist', lw=4)
plt.hist(musv, density=True, label='Actual Data',bins= 80);
plt.title('Technology Distribution')
plt.legend();
